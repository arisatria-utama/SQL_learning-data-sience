# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import plotly.express as px
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/indian_cities.csv')

# %%
data
# Out:
#      Rank        City           State  Population  Metro_Population  Sexratio  \
# 0       1      Mumbai     Maharashtra    12442373          18414288       853
# 1       2       Delhi           Delhi    11034555          16314838       876
# 2       3   Bangalore       Karnataka     8443675           8499399       923
# 3       4   Hyderabad  Andhra Pradesh     6731790           7749334       955
# 4       5   Ahmedabad         Gujarat     5577940           6352254       898
# ..    ...         ...             ...         ...               ...       ...
# 493   494     Gangtok          Sikkim      100286            100286       912
# 494   495       Datia  Madhya Pradesh      100284            100284       900
# 495   496       Nagda  Madhya Pradesh      100039            100039       947
# 496   497    Banswara       Rajasthan       99969            101177       960
# 497   498  Kapurthala          Punjab       98916             98916       839
#
#      Literacy
# 0       89.73
# 1       87.59
# 2       88.71
# 3       83.26
# 4       88.29
# ..        ...
# 493     89.33
# 494     80.56
# 495     80.71
# 496     85.72
# 497     85.08
#
# [498 rows x 7 columns]

# %% [markdown]
# tabel diatas menjelaskan terkait kota di india, data tersebut ditampilkan berupa city (kota) state (bagian/propinsi) populasi , metro populasi sexratio dan literacy yang dilakukan perangkingan berdasarkan populasi dari kota bisa menggunakan intruksi
# data = pd.read_csv('/content/drive/MyDrive/indian_cities.csv')

# %%
top_5_states_population = data.groupby('State')['Population'].sum().nlargest(5).reset_index()
top_5_states_population.columns = ['State', 'Total Population']
display(top_5_states_population)
# Out:
#             State  Total Population
# 0     Maharashtra          38959004
# 1   Uttar Pradesh          26966642
# 2  Andhra Pradesh          18064536
# 3     West Bengal          17990884
# 4         Gujarat          17964399

# %% [markdown]
# tabel diatas menjelaskan 5 state dengan populasi tertinggi

# %%
# Create a bar plot for top 5 states by population
plt.figure(figsize=(12, 7))
sns.barplot(x='State', y='Total Population', data=top_5_states_population, palette='magma')
plt.title('Top 5 Negara Bagian dengan Populasi Terpadat')
plt.xlabel('Negara Bagian')
plt.ylabel('Total Populasi')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2026/955687075.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='State', y='Total Population', data=top_5_states_population, palette='magma')

# %% [markdown]
# diagram diatas menjelaskan 5 state dengan populasi terpadat yakni
# 1. maharashtra
# 2. Uttar Pradesh
# 3. Andhra Pradesh
# 4. West Bengal
# 5. Gujarat

# %%
# Sort the DataFrame by 'Population' in descending order and select the top 5 cities
top_5_cities_population = data.sort_values(by='Population', ascending=False).head(5)

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='City', y='Population', data=top_5_cities_population, palette='viridis')
plt.title('Top 5 Kota Teratas Berdasarkan Populasi')
plt.xlabel('Kota')
plt.ylabel('Populasi')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2026/848284401.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='City', y='Population', data=top_5_cities_population, palette='viridis')

# %% [markdown]
# diagram diatas menjelaskan terkait 5 kota dengan populasi terpadat di india

# %%
top_5_cities_literacy = data.sort_values(by='Literacy', ascending=False).head(5)
display(top_5_cities_literacy)
# Out:
#      Rank       City    State  Population  Metro_Population  Sexratio  \
# 150   151     Aizawl  Mizoram      293416            293416      1025
# 73     74      Kochi   Kerala      602046           2117990      1027
# 137   138   Thrissur   Kerala      315957           1854783      1075
# 102   103  Kozhikode   Kerala      431560           2030519      1093
# 267   268  Alappuzha   Kerala      174176            241072      1077
#
#      Literacy
# 150     98.36
# 73      97.36
# 137     97.06
# 102     96.53
# 267     96.20

# %% [markdown]
# tabel diatas menggambarkan 5 kota dengan literasi tertinggi

# %%
# Create a bar plot for top 5 cities by literacy
plt.figure(figsize=(10, 6))
sns.barplot(x='City', y='Literacy', data=top_5_cities_literacy, palette='viridis')
plt.title('Top 5 Kota dengan Tingkat Literasi Tertinggi')
plt.xlabel('Kota')
plt.ylabel('Literasi')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2026/1517913859.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='City', y='Literacy', data=top_5_cities_literacy, palette='viridis')

# %% [markdown]
# diagram diatas menjelaskan 5 kota dengan tingkat literasi tertinggi yakni :
# 1. Aizawi
# 2. Kochi
# 3. Thrissur
# 4. Kozhikode
# 5. Alappuzha

# %%
display(top_5_cities_sexratio)
# Out:
#      Rank                City   State  Population  Metro_Population  Sexratio  \
# 102   103           Kozhikode  Kerala      431560           2030519      1093
# 267   268           Alappuzha  Kerala      174176            241072      1077
# 125   126              Kollam  Kerala      348657           1110005      1075
# 137   138            Thrissur  Kerala      315957           1854783      1075
# 60     61  Thiruvananthapuram  Kerala      743691           1687406      1054
#
#      Literacy
# 102     96.53
# 267     96.20
# 125     94.12
# 137     97.06
# 60      95.10

# %% [markdown]
# tabel diatas menjelaskan 5 kota dengan nilai sexratio tertinggi di India

# %%
# Sort the DataFrame by 'Sexratio' in descending order and select the top 5 cities
top_5_cities_sexratio = data.sort_values(by='Sexratio', ascending=False).head(5)

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='City', y='Sexratio', data=top_5_cities_sexratio, palette='magma')
plt.title('Top 5 Kota dengan Rasio Jenis Kelamin (Sexratio) Tertinggi')
plt.xlabel('Kota')
plt.ylabel('Rasio Jenis Kelamin')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2026/2758546088.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='City', y='Sexratio', data=top_5_cities_sexratio, palette='magma')

# %%
display(top_5_cities_sexratio)

# %% [markdown]
# diagram diatas menjelaskan 5 kota teratas dengan sexratio tertinggi sehingga diperoleh kozhikode, Alappuzha, kollam, thissur dan thiruvananthapuram sebagai 5 teratas dari data tersebut

# %%
data.dtypes
# Out:
# Rank                  int64
# City                 object
# State                object
# Population            int64
# Metro_Population      int64
# Sexratio              int64
# Literacy            float64
# dtype: object

# %% [markdown]
# Jenis data (data types) dalam DataFrame berdasarkan output dari sel, sehingga dapat kita rangkum sebagai berikut:
#
#     Rank, Population, Metro_Population, dan Sexratio bertipe int64 (bilangan bulat/integer).
#
#     City dan State bertipe object (biasanya berupa teks/string).
#
#     Literacy bertipe float64 (bilangan desimal/floating-point).
#
# Hal ini menunjukkan bahwa kolom numerik telah diidentifikasi dengan benar sebagai integer atau float, dan kolom kategorikal diidentifikasi sebagai objek.

# %%
data.isnull()
# Out:
#       Rank   City  State  Population  Metro_Population  Sexratio  Literacy
# 0    False  False  False       False             False     False     False
# 1    False  False  False       False             False     False     False
# 2    False  False  False       False             False     False     False
# 3    False  False  False       False             False     False     False
# 4    False  False  False       False             False     False     False
# ..     ...    ...    ...         ...               ...       ...       ...
# 493  False  False  False       False             False     False     False
# 494  False  False  False       False             False     False     False
# 495  False  False  False       False             False     False     False
# 496  False  False  False       False             False     False     False
# 497  False  False  False       False             False     False     False
#
# [498 rows x 7 columns]

# %% [markdown]
# Metode data isnull digunakan untuk mendeteksi nilai yang hilang atau 'null' (sering juga disebut 'NaN' atau 'None') dalam setiap elemen DataFrame. Metode ini akan mengembalikan DataFrame baru dengan ukuran yang sama, di mana setiap nilai adalah True jika data asli adalah null, dan False jika data tersebut ada.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              498 non-null    int64
#  1   City              498 non-null    object
#  2   State             498 non-null    object
#  3   Population        498 non-null    int64
#  4   Metro_Population  498 non-null    int64
#  5   Sexratio          498 non-null    int64
#  6   Literacy          498 non-null    float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 27.4+ KB

# %% [markdown]
# Metode data.info memberikan ringkasan singkat dari DataFrame, yang sangat berguna untuk mendapatkan gambaran cepat tentang dataset. Berdasarkan output dari sel

# %%
data.describe().transpose()
# Out:
#                   count           mean           std       min         25%  \
# Rank              498.0     249.500000  1.439045e+02      1.00     125.250
# Population        498.0  449803.008032  1.029319e+06  98916.00  125642.000
# Metro_Population  498.0  555603.297189  1.501008e+06  98916.00  138462.500
# Sexratio          498.0     932.903614  5.539232e+01    709.00     894.250
# Literacy          498.0      84.261004  6.306394e+00     48.28      80.945
#
#                         50%          75%          max
# Rank                 249.50     373.7500       498.00
# Population        184105.00  349596.0000  12442373.00
# Metro_Population  204806.00  410386.2500  18414288.00
# Sexratio             925.00     975.5000      1093.00
# Literacy              85.18      88.6125        98.36

# %% [markdown]
# Berikut adalah penjelasan dari setiap statistik yang disajikan:
#
#     count: Jumlah nilai non-null dalam setiap kolom. Ini menunjukkan bahwa semua kolom numerik memiliki 498 entri, yang berarti tidak ada nilai yang hilang.
#     mean: Rata-rata dari nilai-nilai dalam kolom.
#         Misalnya, rata-rata Population adalah sekitar 449,803.
#     std: Standar deviasi, yang mengukur seberapa tersebar nilai-nilai dalam kolom dari rata-ratanya.
#         Standar deviasi yang tinggi untuk Population (sekitar 1 juta) menunjukkan variasi yang besar dalam ukuran populasi antar kota.
#     min: Nilai minimum dalam kolom.
#     25% (Q1): Kuartil pertama, yang berarti 25% data berada di bawah nilai ini.
#     50% (Median): Median atau kuartil kedua, yang berarti 50% data berada di bawah nilai ini. Ini seringkali lebih robust terhadap outlier dibandingkan rata-rata.
#     75% (Q3): Kuartil ketiga, yang berarti 75% data berada di bawah nilai ini.
#     max: Nilai maksimum dalam kolom.
#
# Dari output ini, diperoleh tentang distribusi data, seperti berikut ini:
#
#     Population: Memiliki rentang yang sangat luas (dari 98,916 hingga 12,442,373), menunjukkan adanya kota-kota besar dan kecil. Rata-rata populasi jauh lebih tinggi daripada median, mengindikasikan adanya beberapa kota dengan populasi sangat besar yang menarik rata-rata ke atas.
#     Sexratio: Rentangnya dari 709 hingga 1093, dengan rata-rata 932.9, menunjukkan bahwa secara umum ada lebih banyak pria daripada wanita di sebagian besar kota (rasio di bawah 1000).
#     Literacy: Rentangnya dari 48.28% hingga 98.36%, dengan rata-rata 84.26%, menunjukkan tingkat literasi yang bervariasi tetapi umumnya tinggi di kota-kota yang tercakup dalam dataset.

# %%
print(str(data.index))
# Out:
# RangeIndex(start=0, stop=498, step=1)

# %% [markdown]
# Instruksi print(str(data.index)) pada dasarnya meminta untuk menampilkan representasi string dari indeks DataFrame data.
#
# Berikut penjelasannya:
#
#     data.index: Dalam pandas DataFrame, index adalah label untuk baris-baris data. Secara default, jika Anda tidak menentukan indeks kustom, pandas akan membuat RangeIndex yang merupakan urutan bilangan bulat dari 0 hingga n-1 (di mana n adalah jumlah baris).
#
#     str(data.index): Fungsi str() mengonversi objek data.index menjadi representasi string-nya. Ini berguna jika Anda ingin melihat indeks dalam format yang dapat dicetak atau disimpan sebagai teks.
#
#     print(...): Fungsi print() kemudian menampilkan representasi string tersebut ke konsol

# %%
fig = px.scatter(data, x='Population', y='Literacy', color='City', hover_name='City', title='Hubungan antara Populasi, Literasi, dan Kota')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d70994ea-79cd-47e0-bdb6-facab33caaa0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d70994ea-79cd-47e0-bdb6-facab33caaa0")) {                    Plotly.newPlot(                        "d70994ea-79cd-47e0-bdb6-facab33caaa0",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCity=Mumbai\u003cbr\u003ePopulation=%{x}\u003cbr\u003eLiteracy=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Mumbai"],"legendgroup":"Mumbai","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Mumbai","orientation":"v","showlegend":true,"x":[12442373],"xaxis":"x","y":[89.73],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCity=Delhi\u003cbr\u003ePopulation=%{x}\u003cbr\u003eLiteracy=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Delhi"],"legendgroup":"Delhi","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Delhi","orientation":"v","showlegend":true,"x":[11034555],"xaxis":"x","y":[87.59],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCity=Bangalore\u003cbr\u003ePopulation=%{x}\u003cbr\u003eLiteracy=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Bangalore"],"legendgroup":"Bangalore","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Bangalore","orientation":"v","showlegend":true,"x":[8443675],"xaxis":"x","y":[88.71],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCity=Hyderabad\u003cbr\u003ePopulation=%{x}\u003cbr\u003eLiteracy=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Hyderabad"],"legendgroup":"Hyderabad","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Hyderabad","orientation":"v","showlegend":true,"x":[6731790],"xaxis":"x","y":[83.26],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCity=Ahmedabad\u003cbr\u003ePopulation=%{x}\u003cbr\u003eLiteracy=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Ahmedabad"],"legendgroup":"Ahmedabad","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Ahmedabad","orientation":"v","showlegend":true,"x":[5577940],"xaxis":"x","y":[88.29],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCity=Chennai\u003cbr\u003ePopulation=%{x}\u003cbr\u003eLiteracy=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Chennai"],"legendgroup":"Chennai","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Chennai","orientation":"v","showlegend":true,"x":[4646732],"xaxis":"x","y":[90.18],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCity=Kolkata\u003cbr\u003ePopulation=%{x}\u003cbr\u003eLiteracy=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Kolkata"],"legendgroup":"Kolkata","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Kolkata","orientation":"v","showlegend":true,"x":[4496694],"xaxis":"x","y":[86.31],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCity=Surat\u003cbr\u003ePopulation=%{x}\u003cbr\u003eLiteracy=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Surat"],"legendgroup":"Surat","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Surat","orientation":"v","showlegend":true,"x":[4467797],"xaxis":"x","y":[87. ...

# %% [markdown]
# diagram scater tersebut menjelaskan hubungan antara populasi literasi dengan kota yang ada di india

# %% [markdown]
# Adapun maksud dari kode diagram pencar Plotly Express yang diatas ialah:
#
# *   **`fig = px.scatter(data, x='Population', y='Literacy', color='City', hover_name='City', title='Hubungan antara Populasi, Literasi, dan Kota')`**:
#     *   `px.scatter()`: Ini adalah fungsi dari library `plotly.express` yang digunakan untuk membuat diagram pencar (scatter plot).
#     *   `data`: Argumen ini menentukan DataFrame yang akan digunakan untuk plotting, yaitu `data` DataFrame Anda.
#     *   `x='Population'`: Mengatur kolom 'Population' dari DataFrame sebagai sumbu horizontal (x-axis) diagram.
#     *   `y='Literacy'`: Mengatur kolom 'Literacy' dari DataFrame sebagai sumbu vertikal (y-axis) diagram.
#     *   `color='City'`: Menginstruksikan Plotly untuk mewarnai setiap titik data berdasarkan nilai unik di kolom 'City'. Ini membantu membedakan kota-kota yang berbeda dalam plot.
#     *   `hover_name='City'`: Ketika Anda mengarahkan kursor ke titik mana pun di plot, nama kota (dari kolom 'City') akan ditampilkan sebagai informasi hover.
#     *   `title='Hubungan antara Populasi, Literasi, dan Kota'`: Menetapkan judul untuk diagram pencar, yang menjelaskan tujuan plot ini.
#
# *   **`fig.show()`**:
#     *   Metode ini digunakan untuk menampilkan objek figur (`fig`) yang telah dibuat. Ini akan merender diagram pencar interaktif di output sel.
